# %% [markdown]
# # Feature engineering - short version for pylearn2

# %%
import pandas as pd
import numpy as np
building = '740-NTH' #'882-WBW' #
df = pd.read_csv('datasets/'+building+'_elektriciteit_withWeather_clean.csv')
df['Momentum'] = df['Momentum'].astype('datetime64')
df = df.set_index('Momentum', drop=False)

# There is an implicit conversion of timezone. I need to fix it.
df.index = df.index + pd.DateOffset(hours=1)
del df['Momentum']
df['Momentum'] = df.index

df.head()
# Out:
#                      gas [m3]  elektriciteit [kwh]  weekDay   T  FH     U  N  \
# 2008-01-01 01:00:00        62             108.0079        1  45  20  0.99  8
# 2008-01-01 02:00:00        55             111.7935        1  44  20  0.99  3
# 2008-01-01 03:00:00        55             115.6467        1  42  20  0.99  4
# 2008-01-01 04:00:00        54             115.8157        1  38  30  0.99  9
# 2008-01-01 05:00:00        56             115.6636        1  33  30  0.99  9
#
#                      Q            Momentum
# 2008-01-01 01:00:00  0 2008-01-01 01:00:00
# 2008-01-01 02:00:00  0 2008-01-01 02:00:00
# 2008-01-01 03:00:00  0 2008-01-01 03:00:00
# 2008-01-01 04:00:00  0 2008-01-01 04:00:00
# 2008-01-01 05:00:00  0 2008-01-01 05:00:00

# %% [markdown]
# ## Feature engineering

# %%
timeFeatures = ['hour', 'weekDay', 'month', 'year', 'dayOfYear']

for tf in timeFeatures:
    if tf != 'weekDay':
        df[tf] = 0
    
    df['sin' + tf.title()] = 0
    df['cos' + tf.title()] = 0


def addTimeFeatures(s):
    s['hour'] = s['Momentum'].hour
    s['month'] = s['Momentum'].month
    s['year'] = s['Momentum'].year
    s['dayOfYear'] = s['Momentum'].dayofyear
    return s
    
df = df.apply(addTimeFeatures, 1)

for tf in timeFeatures:
    maximum = df[tf].max()
    
    df['sin' + tf.title()] = np.sin(2*np.pi*df[tf]/maximum)
    df['cos' + tf.title()] = np.cos(2*np.pi*df[tf]/maximum)

df.head()
# Out:
#                      gas [m3]  elektriciteit [kwh]  weekDay   T  FH     U  N  \
# 2008-01-01 01:00:00        62             108.0079        1  45  20  0.99  8
# 2008-01-01 02:00:00        55             111.7935        1  44  20  0.99  3
# 2008-01-01 03:00:00        55             115.6467        1  42  20  0.99  4
# 2008-01-01 04:00:00        54             115.8157        1  38  30  0.99  9
# 2008-01-01 05:00:00        56             115.6636        1  33  30  0.99  9
#
#                      Q            Momentum  hour  ...   cosWeekday  month  \
# 2008-01-01 01:00:00  0 2008-01-01 01:00:00     1  ...          0.5      1
# 2008-01-01 02:00:00  0 2008-01-01 02:00:00     2  ...          0.5      1
# 2008-01-01 03:00:00  0 2008-01-01 03:00:00     3  ...          0.5      1
# 2008-01-01 04:00:00  0 2008-01-01 04:00:00     4  ...          0.5      1
# 2008-01-01 05:00:00  0 2008-01-01 05:00:00     5  ...          0.5      1
#
#                      sinMonth  cosMonth  year   sinYear   cosYear  dayOfYear  \
# 2008-01-01 01:00:00       0.5  0.866025  2008 -0.018717  0.999825          1
# 2008-01-01 02:00:00       0.5  0.866025  2008 -0.018717  0.999825          1
# 2008-01-01 03:00:00       0.5  0.866025  2008 -0.018717  0.999825          1
# 2008-01-01 04:00:00       0.5  0.866025  2008 -0.018717  0.999825          1
# 2008-01-01 05:00:00       0.5  0.866025  2008 -0.018717  0.999825          1
#
#                      sinDayofyear  cosDayofyear
# 2008-01-01 01:00:00      0.017166      0.999853
# 2008-01-01 02:00:00      0.017166      0.999853
# 2008-01-01 03:00:00      0.017166      0.999853
# 2008-01-01 04:00:00      0.017166      0.999853
# 2008-01-01 05:00:00      0.017166      0.999853
#
# [5 rows x 23 columns]

# %%
df['gas1HBefore'] = df['gas [m3]'].shift(1)
df['gas2HBefore'] = df['gas [m3]'].shift(2)
df['Tdiff1'] = df['T']-df['T'].shift(1)
df['gasMean15DBefore'] = pd.stats.moments.rolling_mean(df['gas [m3]'].shift(1),360,min_periods=360)
df['gasPeak5HBefore'] = pd.stats.moments.rolling_max(df['gas [m3]'].shift(1),5,min_periods=5)
df['gasSum5HBefore'] = pd.stats.moments.rolling_sum(df['gas [m3]'].shift(1),5,min_periods=5)
df['gasPeak1DBefore'] = pd.stats.moments.rolling_max(df['gas [m3]'].shift(1),24,min_periods=24)
df['gasSum1DBefore'] = pd.stats.moments.rolling_sum(df['gas [m3]'].shift(1),24,min_periods=24)

# %%
df2 = pd.read_csv('datasets/ARIMA_forecast.csv') #, names=['Momentum', 'arima', 'arimaHi']
df2.rename(columns={'Index': 'Momentum', 'predicted': 'arima'}, inplace=True)
df2 = df2.set_index('Momentum', drop=False)

df = df.join(df2[['arima', 'predictedHi']])
df = pd.concat([df[df.arima.notnull()]])
df = df[df.arima.notnull()].sort_index()

# residuals
resid = pd.read_csv('datasets/residuals_year.csv')
resid.rename(columns={'Index': 'Momentum', 'remainder': 'residuals'}, inplace=True)
resid = resid.set_index('Momentum', drop=False)

df = df.join(resid[['residuals', 'trend']], how="inner", sort=True)
df = df[(df.weekDay.notnull()) & (df.arima.notnull())]
df["index"] = df.index
df.drop_duplicates(cols='index', take_last=True, inplace=True)
del df["index"]

# residuals 2
resid = pd.read_csv('datasets/residuals_week.csv')
resid.rename(columns={'Index': 'Momentum', 'remainder':'residualsWeekDays', 'trend': 'trendWeekDays'}, inplace=True)
resid = resid.set_index('Momentum', drop=False)

df = df.join(resid[['residualsWeekDays', 'trendWeekDays']])
df = df[(df.weekDay.notnull()) & (df.arima.notnull())]

#residuals 3
resid = pd.read_csv('datasets/residuals_day.csv')
resid.rename(columns={'Index': 'Momentum', 'remainder':'residualsDays', 'trend': 'trendDays'}, inplace=True)
resid = resid.set_index('Momentum', drop=False)

df = df.join(resid[['residualsDays', 'trendDays']])
df = df[(df.weekDay.notnull()) & (df.arima.notnull())]

#residuals electricity
resid = pd.read_csv('datasets/residuals_electricity_day.csv')
resid.rename(columns={'Index': 'Momentum', 'remainder':'residualsElectricity'}, inplace=True)
resid = resid.set_index('Momentum', drop=False)

df = df.join(resid[['residualsElectricity']])
df = df[(df.weekDay.notnull()) & (df.arima.notnull())]

# memories
df['arimaPeak5HBefore'] = pd.stats.moments.rolling_max(df['arima'],5,min_periods=5)
df['arimaSum5HBefore'] = pd.stats.moments.rolling_sum(df['arima'],5,min_periods=5)

# %%
backtrack = ['elektriciteit [kwh]', 'T', 'gas [m3]']
names = [x+"_peak" for x in backtrack]
names.extend([x+"_mean" for x in backtrack])
for f in backtrack:
    df[f+"_peak"] = pd.stats.moments.rolling_max(df[f].shift(1),5, min_periods=5)
    df[f+"_mean"] = pd.stats.moments.rolling_sum(df[f].shift(1),5, min_periods=5)

# %% [markdown]
# In order to train the neural network easily, the weather columns will be normalized

# %%
def normalizeColumns(df, columns):
    for column in toNormalize:
        max_X = df[column].max()
        min_X = df[column].min()
        
        midrange = (max_X+min_X)/2
        Xrange = (max_X-min_X)
        
        df[column] = (df[column] - midrange) / (Xrange/2)
    return df

toNormalize = ['elektriciteit [kwh]', 'T', 'FH', 'gas1HBefore', 'gas2HBefore', 'arima', 'residuals', 'gasMean15DBefore', 'Tdiff1', 'gasPeak5HBefore', 'gasSum5HBefore','arimaPeak5HBefore','arimaSum5HBefore', 'gasSum1DBefore', 'gasPeak1DBefore', 'residualsDays', 'residualsElectricity']
toNormalize.extend(names)
df = normalizeColumns(df, toNormalize)
df.head()
# Out:
#                      gas [m3]  elektriciteit [kwh]  weekDay         T  \
# 2008-01-21 01:00:00        51            -0.682311        0  0.096267
# 2008-01-21 02:00:00        50            -0.677399        0  0.096267
# 2008-01-21 03:00:00        51            -0.678719        0  0.088409
# 2008-01-21 04:00:00        50            -0.680198        0  0.092338
# 2008-01-21 05:00:00        51            -0.681307        0  0.100196
#
#                            FH     U  N  Q            Momentum  hour  ...   \
# 2008-01-21 01:00:00 -0.090909  0.93  8  0 2008-01-21 01:00:00     1  ...
# 2008-01-21 02:00:00 -0.090909  0.94  8  0 2008-01-21 02:00:00     2  ...
# 2008-01-21 03:00:00 -0.181818  0.95  8  0 2008-01-21 03:00:00     3  ...
# 2008-01-21 04:00:00 -0.090909  0.92  8  0 2008-01-21 04:00:00     4  ...
# 2008-01-21 05:00:00 -0.090909  0.92  8  0 2008-01-21 05:00:00     5  ...
#
#                      trendDays  residualsElectricity  arimaPeak5HBefore  \
# 2008-01-21 01:00:00  53.872755              0.319719                NaN
# 2008-01-21 02:00:00  54.572756              0.309274                NaN
# 2008-01-21 03:00:00  55.272757              0.246029                NaN
# 2008-01-21 04:00:00  55.972757              0.200876                NaN
# 2008-01-21 05:00:00  56.672758              0.068475          -0.269668
#
#                      arimaSum5HBefore  elektriciteit [kwh]_peak  \
# 2008-01-21 01:00:00               NaN                       NaN
# 2008-01-21 02:00:00               NaN                       NaN
# 2008-01-21 03:00:00               NaN                       NaN
# 2008-01-21 04:00:00               NaN                       NaN
# 2008-01-21 05:00:00         -0.226795                       NaN
#
#                      elektriciteit [kwh]_mean  T_peak  T_mean  gas [m3]_peak  \
# 2008-01-21 01:00:00                       NaN     NaN     NaN            NaN
# 2008-01-21 02:00:00                       NaN     NaN     NaN            NaN
# 2008-01-21 03:00:00                       NaN     NaN     NaN            NaN
# 2008-01-21 04:00:00                       NaN     NaN     NaN            NaN
# 2008-01-21 05:00:00                       NaN     NaN     NaN            NaN
#
#                      gas [m3]_mean
# 2008-01-21 01:00:00            NaN
# 2008-01-21 02:00:00            NaN
# 2008-01-21 03:00:00            NaN
# 2008-01-21 04:00:00            NaN
# 2008-01-21 05:00:00            NaN
#
# [5 rows x 48 columns]

# %%
print len(features)-1
# Out:
# 29

# %% [markdown]
# ### Output

# %%
features = ['gas [m3]', 'sinMonth', 'cosMonth', 'sinWeekday', 'cosWeekday', 'sinDayofyear', 'cosDayofyear', 'sinHour', 'cosHour',
            'elektriciteit [kwh]', 'T', 'FH', 'gas1HBefore', 'gas2HBefore', 'arima', 'residuals', 
            'gasMean15DBefore', 'Tdiff1', 'gasSum1DBefore', 'gasPeak1DBefore',
            'arimaPeak5HBefore','arimaSum5HBefore', 'residualsDays', 'residualsElectricity']
features.extend(names)
df = df[(df['gas [m3]'].notnull()) & (df['arimaPeak5HBefore'].notnull()) & (df.residualsWeekDays.notnull()) & (df.residuals.notnull()) & (df['gasMean15DBefore'].notnull())]
df[features].to_csv('datasetsForANNs/'+building+'_Arima4_3.csv', index=False)

# %% [markdown]
# ## Prepare for pylearn2

# %% [markdown]
# ### Shuffling?

# %%
def shuffle(df, n=1, axis=1):
    df = df.copy()
    for _ in range(n):
        df.apply(np.random.shuffle, axis=axis)
    return df
df = shuffle(df)
df.head()
# Out:
#    gas [m3]  sinmonth  cosmonth  elektriciteit [kwh]         T        FH  \
# 0        79       0.5  0.866025             0.327587  0.115914  0.272727
# 1        53       0.5  0.866025             0.347551  0.108055  0.363636
# 2        87       0.5  0.866025             0.372956  0.088409  0.272727
# 3        55       0.5  0.866025             0.372322  0.068762  0.272727
# 4        84       0.5  0.866025             0.325527  0.053045  0.181818
#
#     sinHour   cosHour  sinWeekDay  cosWeekDay     ...      gasSum1DBefore  \
# 0  0.136167 -0.990686           0           1     ...           -0.396501
# 1 -0.136167 -0.990686           0           1     ...           -0.382410
# 2 -0.398401 -0.917211           0           1     ...           -0.381438
# 3 -0.631088 -0.775711           0           1     ...           -0.365403
# 4 -0.816970 -0.576680           0           1     ...           -0.362974
#
#    elektriciteit [kwh]_peak  T_noNorm_peak  gas [m3]_peak  \
# 0                  0.260774          0.112      -0.591331
# 1                  0.327587          0.112      -0.510836
# 2                  0.347551          0.112      -0.510836
# 3                  0.372956          0.100      -0.461300
# 4                  0.372956          0.100      -0.461300
#
#    elektriciteit [kwh]_sum  T_noNorm_sum  gas [m3]_sum  \
# 0                -0.107512      0.135135     -0.495446
# 1                 0.091595      0.137592     -0.449909
# 2                 0.246160      0.137592     -0.446266
# 3                 0.334843      0.129402     -0.382514
# 4                 0.372280      0.123669     -0.402550
#
#    elektriciteit [kwh]_mean  T_noNorm_mean  gas [m3]_mean
# 0                 -0.107512       0.135135      -0.495446
# 1                  0.091595       0.137592      -0.449909
# 2                  0.246160       0.137592      -0.446266
# 3                  0.334843       0.129402      -0.382514
# 4                  0.372280       0.123669      -0.402550
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Train (70%) + test (15%) + valid (15%)

# %%
n = df['T'].count()
splitPoint = int(n*70/100)
train = df.ix[:splitPoint]
rest = df.ix[splitPoint:]
train[features].to_csv('train.csv', header=False, index=False)

# Reset index
rest = rest.reset_index(drop=True)

n = rest['T'].count()
splitPoint = int(n*50/100)
valid = rest.ix[:splitPoint]
test = rest.ix[splitPoint:]
test[features].to_csv('testY.csv', header=False, index=False)
featuresNoY = features[1:]
test[featuresNoY].to_csv('test.csv', header=False, index=False)
valid[features].to_csv('valid.csv', header=False, index=False)

# %% [markdown]
# ## Results

# %%
rr = pd.read_csv('predict.csv', names=["predicted"])
rr2 = pd.read_csv('testY.csv', names=["actual"]+["" for x in range(29)])
rr['actual'] = rr2['actual'].values
rr['Momentum'] = test['Momentum'].values

rr = rr.set_index('Momentum', drop=False)
rr2.head()
# Out:
#    actual                                                              \
# 0      23 -0.730419 -0.730419 -0.730419 -0.730419 -0.730419 -0.730419
# 1      17 -0.688525 -0.688525 -0.688525 -0.688525 -0.688525 -0.688525
# 2      24 -0.657559 -0.657559 -0.657559 -0.657559 -0.657559 -0.657559
# 3      32 -0.759563 -0.759563 -0.759563 -0.759563 -0.759563 -0.759563
# 4      23 -0.775956 -0.775956 -0.775956 -0.775956 -0.775956 -0.775956
#
#                                    ...                                   \
# 0 -0.730419 -0.730419 -0.730419    ...    -0.730419 -0.730419 -0.730419
# 1 -0.688525 -0.688525 -0.688525    ...    -0.688525 -0.688525 -0.688525
# 2 -0.657559 -0.657559 -0.657559    ...    -0.657559 -0.657559 -0.657559
# 3 -0.759563 -0.759563 -0.759563    ...    -0.759563 -0.759563 -0.759563
# 4 -0.775956 -0.775956 -0.775956    ...    -0.775956 -0.775956 -0.775956
#
#
# 0 -0.730419 -0.730419 -0.730419 -0.730419 -0.730419 -0.730419 -0.730419
# 1 -0.688525 -0.688525 -0.688525 -0.688525 -0.688525 -0.688525 -0.688525
# 2 -0.657559 -0.657559 -0.657559 -0.657559 -0.657559 -0.657559 -0.657559
# 3 -0.759563 -0.759563 -0.759563 -0.759563 -0.759563 -0.759563 -0.759563
# 4 -0.775956 -0.775956 -0.775956 -0.775956 -0.775956 -0.775956 -0.775956
#
# [5 rows x 30 columns]

# %%
import ml_metrics as metrics
def nonZeroValues(actual, predicted):

    actual = np.array(actual)
    indexes = np.where(actual == 0)[0]

    actual = [v for i,v in enumerate(actual) if i not in frozenset(indexes)]
    predicted = [v for i,v in enumerate(predicted) if i not in frozenset(indexes)] 
    
    return (actual, predicted)

def mape(actual, predicted):
    """
    Computes the mean absolute percentage error.

    This function computes the mean absolute percentage error between two lists
    of numbers. 
    BE CAREFUL: it can cause division-by-zero errors!

    Parameters
    ----------
    actual : list of numbers, numpy array
             The ground truth value
    predicted : same type as actual
                The predicted value

    Returns
    -------
    score : double
            The mean absolute percentage error between actual and predicted

    """
    actual, predicted = nonZeroValues(actual, predicted)
    return np.mean(np.divide(np.abs(np.array(actual) - np.array(predicted)), np.array(actual))) * 100


print "MAPE: ", mape(rr['actual'].values, rr['predicted'].values)
print "RMSE: ", metrics.rmse(rr['actual'].values, rr['predicted'].values)
print "MAE: ", metrics.mae(rr['actual'].values, rr['predicted'].values)
# Out:
# MAPE:
# 18.7127035611
# RMSE:  7.84458127966
# MAE:  4.56407733579

# %% [markdown]
# ## Plot

# %%
from sklearn.metrics import mean_squared_error
import math
rr['rmse'] = 0
def rmseDF(s):
    s['predicted'] = abs(s['predicted'])
    s['rmse'] = math.sqrt(mean_squared_error([s.actual], [s.predicted]))
    return s

rr = rr.apply(rmseDF, 1)

# %%
rr[['predicted', 'actual', 'rmse']].head(1200).tail(50).plot()

# %%
rr[['predicted', 'actual', 'rmse']].head(500).tail(300).plot(figsize=(30,17))

# %%
rr[['actual']].head(500).tail(300).plot(figsize=(30,17))

# %% [markdown]
# ## Outliers:

# %%
from scipy import stats
rr['outlier'] = 0
#ci = scipy.stats.chisquare(rr['predicted'], rr['actual'])
n = df['gas [m3]'].count()
n = rr['actual'].count()
c1, c2 = stats.chi2.ppf([0.025,1-0.025],n)
l = sqrt(n/c2)*7.84
r = sqrt(n/c1)*7.84

import ml_metrics as metrics
err = metrics.rmse(rr['actual'].values, rr['predicted'].values)

print l, " ", r, " err:", err, " ", c1, " ", c2
# Out:
# 7.72139880241   7.96232768906  err: 7.84434704325   7890.83713787   8390.95140695

# %%
rr.head()
# Out:
#                      predicted  actual            Momentum       rmse  outlier
# Momentum
# 2013-04-25 21:00:00  18.778698      23 2013-04-25 21:00:00   4.221302        0
# 2013-04-25 22:00:00  18.235688      17 2013-04-25 22:00:00   1.235688        0
# 2013-04-25 23:00:00  16.570606      24 2013-04-25 23:00:00   7.429394        0
# 2013-04-26 00:00:00  19.588069      32 2013-04-26 00:00:00  12.411931        0
# 2013-04-26 01:00:00  25.742483      23 2013-04-26 01:00:00   2.742483        0

# %%
def contro(s):
    if abs(s['predicted']-s['actual']) > r*4.5:
        s['out2'] = 100
    else:
        s['out2'] = 0
    return s

rr = rr.apply(contro,1)

# %%
rr[['actual', 'predicted', 'out2']].head(500).tail(300).plot(figsize=(30,17), style=[None, '--', 'o'])

# %%
rr[['actual', 'predicted', 'out2']].head(3000).plot(figsize=(105,17), style=[None, '--', 'o'])

# %%
ax = rr[['predicted', 'actual', 'out2']].tail(400).plot(figsize=(20,7), grid=False, colormap='gray', legend=True, style=['--','k-', 'o'])
ax.set_ylabel("Gas (m$^3$)")
ax.set_xlabel("Hours")
ax.autoscale_view('tight')
plt.savefig('latexGraphs/outliersSynt.eps', format='eps', dpi=330,bbox_inches='tight')
